# %%
import sys
import os

# Add thesrc directory to the Python path
notebook_dir = os.path.abspath("")
# Go up one level to the project root
project_root = os.path.dirname(notebook_dir)

src_dir = os.path.join(project_root, "src")
sys.path.insert(0, src_dir)

# %%
import lkdata

# %%
# %load_ext autoreload
# %autoreload 2

# %%
tpf = lkdata.TargetPixelFile(
    "/Users/nthom/.lightkurve/cache/mastDownload/TESS/tess2018206045859-s0001-0000000273985862-0120-s/tess2018206045859-s0001-0000000273985862-0120-s_tp.fits"
)

# %%
tpf
# Out:
# TargetPixelFile Object (ID: TIC 273985862)

# %%
tpf.data_cubes
# Out:
# Data Products:
# {'RAW_CNTS': 📘 DataCube (20076, 11, 11), 'FLUX': 📘 DataCube (20076, 11, 11), 'FLUX_BKG': 📘 DataCube (20076, 11, 11), 'FLUX_ERR': 📕 ErrorCube (20076, 11, 11), 'FLUX_BKG_ERR': 📕 ErrorCube (20076, 11, 11)},
# Error Products:
# {},
# Properties:
# []

# %%
tpf.len
# Out:
# 20076

# %%
tpf.ra, tpf.dec
# Out:
# (30.5788356733675, -83.2106104061536)

# %%
tpf.column, tpf.row
# Out:
# (405, 1133)

# %%
tpf.pos_corr1
# Out:
# array([        nan, -0.06463072, -0.03205149, ..., -0.04926089,
#        -0.03635252, -0.04935435])

# %%
tpf.pos_corr2
# Out:
# array([        nan, -0.01258672,  0.02175389, ..., -0.08499582,
#        -0.05222085, -0.08247187])

# %%
tpf.shape
# Out:
# (20076, 121)

# %%
tpf.time
# Out:
# <Time object: scale='tdb' format='btjd' value=[1325.29632048 1325.29770935 1325.29909822 ... 1353.17500235 1353.1763912
#  1353.17778005]>

# %%
tpf.cadenceno
# Out:
# array([70444., 70445., 70446., ..., 90517., 90518., 90519.])

# %%
tpf.nan_time_mask
# Out:
# array([False, False, False, ..., False, False, False])

# %%
tpf.flux
# Out:
# <Quantity [[26.21074677, 17.74368095, 22.19079971, ...,  8.62978554,
#             22.33022499, 41.81694412],
#            [28.21045876, 14.50713158, 18.08428574, ...,  8.39988613,
#             22.46102905, 45.69250107],
#            [30.28063011, 16.21681404, 19.69126701, ..., 10.13190746,
#             23.15697479, 46.55126572],
#            ...,
#            [25.72852707, 17.89391518, 20.19951248, ...,  8.92148018,
#             19.50483131, 42.59098816],
#            [27.27593231, 17.64684677, 20.19533157, ...,  7.07993412,
#             19.01613045, 46.99532318],
#            [27.41474152, 15.2153759 , 21.8830452 , ...,  8.24302387,
#             20.28627777, 43.86603928]] electron / s>

# %%
tpf.flux_err
# Out:
# <Quantity [[1.42499828, 1.39006341, 1.40959883, ..., 1.35473514,
#             1.407372  , 1.49718893],
#            [1.43223023, 1.38286269, 1.39585841, ..., 1.35707521,
#             1.40716875, 1.51338911],
#            [1.43823874, 1.38581598, 1.40253937, ..., 1.36269212,
#             1.41329551, 1.51766074],
#            ...,
#            [1.43165088, 1.39976323, 1.41231179, ..., 1.36302567,
#             1.40184021, 1.51357639],
#            [1.43370497, 1.39749444, 1.4115479 , ..., 1.35563362,
#             1.3979274 , 1.52970278],
#            [1.43451607, 1.38743138, 1.41256237, ..., 1.36023855,
#             1.40420127, 1.51652992]] electron / s>

# %%
tpf.get_header()
# Out:
# SIMPLE  =                    T / conforms to FITS standards
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T / file contains extensions
# NEXTEND =                    3 / number of standard extensions
# EXTNAME = 'PRIMARY '           / name of extension
# EXTVER  =                    1 / extension version number (not format version)
# SIMDATA =                    F / file is based on simulated data
# ORIGIN  = 'NASA/Ames'          / institution responsible for creating this file
# DATE    = '2020-09-12'         / file creation date.
# TSTART  =    1325.295626161439 / observation start time in BTJD
# TSTOP   =    1353.178474356824 / observation stop time in BTJD
# DATE-OBS= '2018-07-25T19:04:32.916' / TSTART as UTC calendar date
# DATE-END= '2018-08-22T16:15:51.000' / TSTOP as UTC calendar date
# CREATOR = '26405 TargetPixelExporterPipelineModule' / pipeline job and program u
# ...

# %%
tpf.get_keyword("NAXIS", ext=1)
# Out:
# 2
